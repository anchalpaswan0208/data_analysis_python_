# %%
import pandas as pd

# %%
data = {
    "name" : ["Anchal" , "Shubh" , "Riya"],
    "Age":[20,21 ,22]
}

df = pd.DataFrame(data)
data
# Out:
# {'name': ['Anchal', 'Shubh', 'Riya'], 'Age': [20, 21, 22]}

# %%
df.to_csv("student.csv" , index = False)
